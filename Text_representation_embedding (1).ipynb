# %% [markdown]
# 1. [Classic 3](#Classic_3)
# - [NG5](#NG5)
# - [NG20](#NG20)
# - [Reuters8](#Reuteurs_8)

# %% [markdown]
# ## Dépendances

# %%
import numpy as np#utils
import os     

from gensim.models import Word2Vec#gensim
from gensim.models import FastText
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import remove_stopwords

from sklearn.feature_extraction.text import TfidfVectorizer#sci-kit learn
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import normalized_mutual_info_score
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# # Classic_3
# ## Data
# On se place au même niveau que le dossier classic qui contient toutes les données

# %%
all_files = os.listdir("classic/")   
print(all_files)
# Out:
# ['cisi.000352', 'cisi.000314', 'cisi.000825', 'med.000091', 'cran.001282', 'med.000019', 'med.000234', 'cisi.000643', 'cran.000007', 'cisi.000906', 'cran.000084', 'cran.000640', 'med.000129', 'cran.000631', 'cisi.001427', 'med.000501', 'med.000267', 'cran.000354', 'cisi.000321', 'med.000576', 'cran.001322', 'cisi.000659', 'med.000524', 'cran.000344', 'med.000934', 'cran.001115', 'cran.000407', 'cisi.000323', 'cran.000649', 'cran.000545', 'cisi.000386', 'med.000332', 'med.000315', 'cisi.000274', 'cisi.000942', 'cran.001267', 'med.000801', 'cran.000940', 'cisi.000220', 'cran.000789', 'med.000704', 'cisi.001109', 'cisi.000748', 'cran.000206', 'cran.001269', 'med.000368', 'cran.000073', 'med.000423', 'cisi.000813', 'med.000476', 'cran.001249', 'med.000183', 'cisi.000451', 'cisi.000339', 'cisi.001329', 'cisi.000434', 'cran.000454', 'cisi.001242', 'cran.001019', 'cisi.000376', 'cisi.001183', 'cisi.000665', 'med.000417', 'cran.000164', 'cran.000486', 'cran.000102', 'cisi.000301', 'cisi.001096', 'cisi.000888', 'med.000168', 'med.000112', 'cisi.000727', 'med.000767', 'cran.000601', 'cran.000284', 'cisi.000881', 'med.000482', 'cran.000870', 'cisi.001302', 'med.000297', 'cisi.001246', 'med.000946', 'med.000122', 'cisi.000792', 'med.000593', 'cran.000008', 'cisi.000758', 'cisi.000974', 'cran.000983', 'cran.001305', 'cisi.001154', 'cran.000795', 'cisi.000581', 'cran.000085', 'med.000661', 'cisi.000195', 'cisi.000686', 'med.000589', 'cisi.000998', 'cisi.000408', 'cisi.000579', 'cran.000321', 'cisi.001405', 'cisi.001219', 'cran.000154', 'med.001005', 'cran.001072', 'cisi.000035', 'cran.001032', 'cran.001272', 'cran.001380', 'cisi.000743', 'med.000401', 'med.000825', 'med.000202', 'med.000138', 'cran.000330', 'med.000407', 'med.000191', 'cisi.000008', 'cisi.000439', 'cran.000671', 'cisi.001317', 'cisi.001377', 'cisi.000559', 'med.000687', 'med.000280', 'cran.000826', 'cisi.001244', 'med.000013', 'cisi.000302', 'cisi.000016', 'med.000084', 'cran.001120', 'med.000656', 'cisi.000914', 'med.000855', 'cran.000323', 'cran.000493', 'cisi.000820', 'cisi.000140', 'cisi.000585', 'cran.000171', 'med.000803', 'med.000829', 'cran.001027', 'cisi.000277', 'cran.001373', 'cran.001220', 'med.000507', 'cran.001252', 'cran.000606', 'med.000481', 'med.000189', 'med.000402', 'cran.001070', 'cisi.001408', 'cisi.000153', 'cran.000536', 'med.000313', 'med.000379', 'cisi.000295', 'med.000298', 'cisi.001432', 'cisi.000112', 'cran.001238', 'cran.001310', 'med.000130', 'cisi.000708', 'cisi.000663', 'med.000614', 'cisi.001046', 'cran.000946', 'cisi.001370', 'med.000867', 'cisi.000573', 'cisi.001157', 'cisi.000102', 'cisi.000489', 'cisi.000676', 'cran.000948', 'med.000655', 'cran.000132', 'cran.000659', 'cisi.001403', 'cran.000739', 'cisi.000977', 'cran.001262', 'cisi.001226', 'med.000411', 'cisi.000330', 'cisi.000771', 'med.000735', 'cisi.000177', 'cisi.001451', 'cran.001211', 'med.000863', 'cisi.001104', 'cisi.000789', 'cran.000930', 'cisi.001257', 'cisi.000152', 'cisi.000993', 'cisi.001158', 'cisi.000714', 'med.000713', 'cran.000070', 'cisi.000695', 'cisi.000242', 'cisi.000734', 'cran.000921', 'cran.000706', 'cisi.000248', 'cisi.001397', 'med.000378', 'med.000092', 'cisi.000410', 'cran.001150', 'cran.001319', 'cisi.000039', 'cisi.000483', 'med.000839', 'med.000809', 'cisi.001165', 'cran.000452', 'cran.001024', 'cisi.000429', 'cisi.000103', 'cisi.000385', 'cran.000031', 'cran.001266', 'cran.001369', 'med.000725', 'med.000104', 'cisi.000683', 'med.000547', 'cran.000798', 'cisi.001094', 'cran.000446', 'cisi.000988', 'cisi.000026', 'med.000268', 'cran.000987', 'cran.000761', 'cran.000117', 'cran.000889', 'cisi.000003', 'cisi.001074', 'cisi.000699', 'cisi.001195', 'cisi.001395', 'med.000634', 'med.000472', 'cran.000665', 'cran.001104', 'cisi.001022', 'cisi.001007', 'cran.001065', 'cran.000197', 'med.000023', 'cran.000958', 'cran.000305', 'cisi.001339', 'cisi.001224', 'cran.001215', 'cisi.000997', 'cran.000421', 'cisi.001134', 'cisi.001423', 'cisi.000006', 'cisi.000484', 'me ...

# %%
for i in range(len(all_files)):
    all_files[i]="classic/"+all_files[i]

# %%
all_files[47]
# Out:
# 'classic/med.000423'

# %%
text_labels=[]
start=len("classic/")
for path in all_files:
    text_labels.append(path[start:start+4])

# %%
text_labels[0:8
           ]
# Out:
# ['cisi', 'cisi', 'cisi', 'med.', 'cran', 'med.', 'med.', 'cisi']

# %%
label_dict={'cisi':0,'cran':1,'med.':2}

# %% [markdown]
# Le document n°47 (med.000423) est vide => on vérifie la taille du document avant d'ajouter le label, et, ainsi on ne tient plus compte de ce document.

# %%
data=[]
for file_path in all_files:
    with open(file_path) as file:
        doc=[]
        for line in file:
            doc+=simple_preprocess(remove_stopwords(line))
        data.append(doc)

# %%
print(data[0])
# Out:
# ['developing', 'multi', 'media', 'libraries', 'this', 'book', 'presents', 'concept', 'modern', 'library', 'comprehensive', 'resource', 'center', 'the', 'philosophy', 'objectives', 'center', 'clarified', 'desirable', 'practices', 'selection', 'acquisition', 'nonbook', 'audiovisual', 'materials', 'interchangeably', 'defined', 'materials', 'communicate', 'primarily', 'aural', 'visual', 'stimuli', 'recommended', 'information', 'pertinent', 'facilitating', 'tasks', 'their', 'organization', 'general', 'discussed', 'emphasis', 'necessity', 'basic', 'decisions', 'policies', 'cataloging', 'physical', 'processing', 'treated', 'particular', 'demonstrating', 'accepted', 'library', 'practices', 'flexible', 'allow', 'adaptation', 'individual', 'library', 'specific', 'clientele', 'realistic', 'methods', 'handling', 'different', 'kinds', 'nonbook', 'materials', 'demonstrated', 'treating', 'type', 'separately', 'many', 'easy', 'to', 'follow', 'cataloging', 'examples', 'presented', 'and', 'consistent', 'established', 'library', 'routine', 'practical', 'information', 'provided', 'selection', 'acquisition', 'physical', 'processing', 'storage', 'equipment', 'work', 'flow', 'charts', 'included', 'present', 'graphic', 'demonstration', 'efficient', 'procedures']

# %%
joined_data=[]
for doc in data:
    joined_data.append(" ".join(doc))

# %%
len(all_files),len(data),len(joined_data)
# Out:
# (3891, 3891, 3891)

# %%
labels=[]
for i,label in enumerate(text_labels):
    if len(data[i])!=0:
        labels.append(label_dict[label])

# %%
len(labels)
# Out:
# 3890

# %%
labels[0:8]
# Out:
# [0, 0, 0, 2, 1, 2, 2, 0]

# %% [markdown]
# ## Term Document Frequency Matrix

# %% [markdown]
# Commenter tous les paramètres

# %%
tf=TfidfVectorizer(input='content',lowercase=False, use_idf=True,min_df=1, sublinear_tf=False)
matrix=tf.fit_transform(joined_data)
vocabulary = tf.vocabulary_

# %%
matrix.shape
# Out:
# (3891, 20238)

# %%
np.array(matrix[0].todense())
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
mot='developing'
index_mot=vocabulary[mot]
index_doc=0
np.array(matrix[index_doc].todense())[0][index_mot]
# Out:
# 0.081070581685123

# %%
print(vocabulary)
# Out:
# {'developing': 4860, 'multi': 11676, 'media': 11027, 'libraries': 10308, 'this': 18331, 'book': 2057, 'presents': 14196, 'concept': 3504, 'modern': 11482, 'library': 10309, 'comprehensive': 3441, 'resource': 15593, 'center': 2642, 'the': 18232, 'philosophy': 13473, 'objectives': 12383, 'clarified': 3019, 'desirable': 4785, 'practices': 14018, 'selection': 16291, 'acquisition': 220, 'nonbook': 12111, 'audiovisual': 1465, 'materials': 10926, 'interchangeably': 9354, 'defined': 4530, 'communicate': 3336, 'primarily': 14266, 'aural': 1474, 'visual': 19761, 'stimuli': 17321, 'recommended': 15139, 'information': 9106, 'pertinent': 13398, 'facilitating': 6640, 'tasks': 18023, 'their': 18236, 'organization': 12678, 'general': 7457, 'discussed': 5146, 'emphasis': 5853, 'necessity': 11877, 'basic': 1679, 'decisions': 4462, 'policies': 13796, 'cataloging': 2538, 'physical': 13542, 'processing': 14334, 'treated': 18758, 'particular': 13114, 'demonstrating': 4640, 'accepted': 110, 'flexible': 7000, 'allow': 648, 'adaptation': 273, 'individual': 8996, 'specific': 16999, 'clientele': 3072, 'realistic': 15038, 'methods': 11220, 'handling': 7934, 'different': 4971, 'kinds': 9943, 'demonstrated': 4638, 'treating': 18760, 'type': 18963, 'separately': 16381, 'many': 10841, 'easy': 5590, 'to': 18496, 'follow': 7080, 'examples': 6347, 'presented': 14193, 'and': 849, 'consistent': 3688, 'established': 6209, 'routine': 15926, 'practical': 14013, 'provided': 14577, 'storage': 17348, 'equipment': 6140, 'work': 20099, 'flow': 7020, 'charts': 2771, 'included': 8890, 'present': 14190, 'graphic': 7754, 'demonstration': 4641, 'efficient': 5682, 'procedures': 14325, 'citation': 2987, 'measures': 11008, 'hard': 7953, 'science': 16150, 'soft': 16875, 'technology': 18075, 'nonscience': 12199, 'perhaps': 13298, 'fundamental': 7340, 'problem': 14315, 'scientific': 16152, 'industry': 9020, 'special': 16984, 'happens': 7946, 'deal': 4410, 'material': 10924, 'having': 7987, 'content': 3758, 'technical': 18065, 'librarianship': 10307, 'involves': 9578, 'applied': 1084, 'books': 2061, 'esoteric': 6193, 'vocabulary': 19786, 'mathematics': 10938, 'my': 11753, 'reason': 15065, 'choosing': 2882, 'contribution': 3810, 'strategic': 17373, 'conference': 3566, 'know': 9974, 'historian': 8253, 'greatest': 7778, 'useful': 19428, 'advances': 390, 'technologies': 18073, 'come': 3289, 'research': 15538, 'trained': 18634, 'people': 13259, 'trying': 18863, 'society': 16863, 'aimed': 539, 'furthering': 7362, 'understanding': 19122, 'curiousity': 4233, 'powered': 13999, 'latest': 10121, 'instrumentation': 9279, 'devised': 4874, 'suspect': 17816, 'new': 12011, 'indexing': 8967, 'tools': 18534, 'handlings': 7935, 'scientists': 16155, 'solving': 16903, 'problems': 14318, 'designed': 4778, 'it': 9704, 'clear': 3057, 'however': 8390, 'bring': 2175, 'success': 17604, 'solutions': 16898, 'ultimately': 19006, 'emerge': 5828, 'progress': 14398, 'documentation': 5329, 'development': 4861, 'precis': 14060, 'theoretical': 18251, 'history': 8261, 'before': 1731, 'starting': 17216, 'trace': 18602, 'beginnings': 1737, 'shall': 16484, 'briefly': 2170, 'form': 7133, 'serve': 16430, 'introduction': 9518, 'familiar': 6685, 'system': 17924, 'help': 8064, 'explain': 6490, 'relevance': 15372, 'historical': 8256, 'sections': 16237, 'machine': 10673, 'produced': 14342, 'alphabetical': 669, 'based': 1675, 'syntax': 17906, 'derived': 4739, 'study': 17453, 'natural': 11842, 'language': 10085, 'developed': 4858, 'principles': 14282, 'classification': 3036, 'preserved': 14199, 'context': 3762, 'differs': 4982, 'respects': 15601, 'traditional': 18625, 'indexes': 8966, 'lists': 10437, 'subject': 17504, 'headings': 8009, 'like': 10342, 'coates': 3145, 'british': 2183, 'index': 8961, 'consists': 3691, 'essentially': 6203, 'set': 16443, 'working': 20105, 'prescribed': 14183, 'list': 10430, 'terms': 18176, 'phrases': 13529, 'firmly': 6939, 'open': 12581, 'ended': 5919, 'means': 11000, 'admitted': 355, 'time': 18439, 's ...

# %% [markdown]
# ## Embedding
# ### Word2Vec

# %%
model = Word2Vec(
        data,
        size=150,#taile du vecteur d'embedding pour chaque mot
        window=10,
        min_count=1,
        workers=10)
model.train(data, total_examples=len(data), epochs=10)
# Out:
# (3157014, 3211400)

# %%
model.wv.most_similar(positive="disorders",topn=6)
# Out:
# /home/paul/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('disorder', 0.9854819178581238),
#  ('manifestations', 0.9698967933654785),
#  ('etiology', 0.9621296525001526),
#  ('neuropathy', 0.9607358574867249),
#  ('neurological', 0.9578737020492554),
#  ('disease', 0.956839919090271)]

# %% [markdown]
# ### FastText

# %%
model = FastText(
        data,
        size=150,#taille du vecteur d'embedding pour chaque mot
        window=10,
        min_count=1,
        workers=10)
model.build_vocab(data,update=True)
model.train(data, total_examples=len(data), epochs=10)

# %% [markdown]
# ### Sans tenir compte de TF-IDF

# %%
D=[]
for document in data:
    D_doc=[]
    for mot in document:
        D_doc.append(model.wv.word_vec(mot))
    D.append(D_doc)

# %% [markdown]
# ###  En tenant compte de TF-IDF
# Sinon commenter indexmot, valeurtf

# %%
D=[]
for index_doc, document in enumerate(data):
    D_doc=[]
    for mot in document:
        index_mot=vocabulary[mot]
        valeur_tf_idf=np.array(matrix[index_doc].todense())[0][index_mot]
        D_doc.append(valeur_tf_idf*model.wv.word_vec(mot))
    D.append(D_doc)

# %%
len(D),len(D[0]),len(D[0][0])
# Out:
# (3891, 104, 150)

# %%
for idx, document in enumerate(D):
    if len(document)==0:
        print("doc vide", idx)
# Out:
# doc vide 47

# %%
D[47],data[47]
# Out:
# ([], [])

# %% [markdown]
# ## SVD

# %% [markdown]
# Le document n°47 (med.000423) est vide => on vérifie la taille du document avant de faire la transformation SVD afin de ne pas avoir d'erreur, et, ainsi on ne tient plus compte de ce document (i.e. on ne l'ajoute pas dans la matrice M).

# %%
M2=[]### document représenté par u1 
M3=[]### document représenté par u1 + u2 
svd = TruncatedSVD(n_components=2, n_iter=7, random_state=42)

for document in D:
    if len(document)!=0:
        svd.fit(document)

        M2.append(svd.components_[0])#[0] to transform 2D array to 1D

        M3.append(svd.components_[0]+svd.components_[1])#u1 + u2

# %%
len(M2)
# Out:
# 3890

# %% [markdown]
# On a 3890 doc au lieu de 3891 à cause du document vide

# %% [markdown]
# ## Clustering
# ### K-Means

# %%
M3[1]
# Out:
# array([-1.73241809e-01,  1.35850802e-01, -9.10314098e-02,  3.80673289e-01,
#        -3.17681357e-02,  1.47507429e-01, -1.79868899e-02,  1.36218995e-01,
#         3.17583442e-01,  1.63838997e-01,  8.03014338e-02, -1.43832266e-02,
#        -1.02670707e-01,  9.39137787e-02, -4.30801325e-02, -2.76527796e-02,
#         9.11340863e-03, -9.87771004e-02,  2.60553285e-02, -6.77368790e-02,
#        -2.11172760e-01,  9.30560455e-02,  2.87764706e-02, -1.14330284e-01,
#        -1.76678859e-02, -3.07687223e-02,  5.93233779e-02,  7.53355399e-02,
#         1.64799541e-01, -8.87594968e-02, -1.16990224e-01,  1.88942105e-01,
#         6.42281473e-02, -4.32479978e-02,  9.15081501e-02,  1.09431267e-01,
#         1.02018453e-01, -7.38774985e-02, -6.83632344e-02,  4.30615768e-02,
#        -9.98854786e-02, -2.57531703e-01,  1.67391360e-01,  7.98855126e-02,
#         1.20164484e-01, -2.25182250e-01, -4.19303067e-02, -8.98555964e-02,
#         3.87181230e-02, -6.00146167e-02,  1.09158419e-01,  1.19382113e-01,
#        -1.76551387e-01, -4.99031693e-02,  3.73668969e-03, -2.53178440e-02,
#        -1.17098846e-01,  4.94532138e-02, -5.59537336e-02, -1.44310281e-01,
#        -1.38130859e-01,  5.48917800e-02, -2.35280767e-03, -7.51701146e-02,
#        -2.43196219e-01, -1.92024950e-02,  8.22380483e-02,  1.22912228e-01,
#         4.83699664e-02,  4.39284258e-02,  9.15834978e-02,  2.10097164e-01,
#        -1.11162663e-04,  2.79529929e-01, -2.69402564e-02,  1.08523630e-02,
#        -1.02436252e-01,  3.68227512e-02, -1.32794231e-01, -2.09620431e-01,
#         1.28980339e-01,  1.72480997e-02, -6.99489564e-02, -7.67472237e-02,
#         5.94834685e-02,  8.62405822e-02,  8.14507157e-03, -1.04358464e-01,
#        -3.92944813e-02,  5.20558059e-02,  1.56192370e-02,  1.86368674e-01,
#        -1.43587455e-01,  3.97716276e-02, -6.62645251e-02,  1.33160561e-01,
#         1.20017126e-01, -9.63202417e-02,  1.40145749e-01,  1.86182503e-02,
#         1.18490838e-01, -4.15707082e-02,  1.60671949e-01, -3.33345979e-02,
#        -3.60777229e-02,  1.60030872e-02, -1.00861132e-01,  1.36830360e-02,
#         5.50742783e-02,  1.29465461e-01, -4.51844484e-02,  1.47200599e-02,
#        -2.99303420e-02,  1.32614896e-01,  6.18870892e-02,  2.39863485e-01,
#         1.59966722e-01,  1.91990405e-01,  2.46299021e-02, -6.93090167e-03,
#        -1.25865072e-01,  2.30211206e-02, -1.48752913e-01, -7.35835209e-02,
#         5.03855944e-02,  1.31844729e-01,  1.30892873e-01, -9.22962278e-02,
#         7.45348632e-02,  2.86360383e-02, -7.22211078e-02, -8.32206011e-02,
#         8.00444707e-02,  7.63714463e-02, -7.21555129e-02, -1.79811761e-01,
#        -9.53825191e-02, -3.19266528e-01, -8.08365941e-02, -1.32029817e-01,
#        -2.59207003e-02, -2.26840302e-02,  1.05465330e-01, -1.61606744e-02,
#         3.95323429e-03, -1.76420957e-01, -1.45826526e-02, -3.98487449e-02,
#         6.72703907e-02,  1.59551069e-01], dtype=float32)

# %%
kmeans = KMeans(n_clusters=3,
               init='k-means++',
               n_init=10,
               n_jobs=-1).fit(M3)

# %%
y_kmeans = kmeans.predict(M3)

# %%
y_kmeans[0:10]
# Out:
# array([0, 0, 0, 2, 1, 2, 2, 0, 1, 0], dtype=int32)

# %%
y_kmeans.shape
# Out:
# (3890,)

# %%
print("%.3f" % adjusted_rand_score(labels, y_kmeans), "%.3f" % accuracy_score(labels, y_kmeans), "%.3f" % normalized_mutual_info_score(labels, y_kmeans))
# Out:
# 0.745 0.907 0.667
# /home/paul/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# Avant le preproccess on avait
# (0.731, 0.234, 0.659) pour u1
#
# et
# (0.676, 0.0589, 0.591) pour u1+u2

# %% [markdown]
# # NG5
# ## Data

# %%
from sklearn.datasets import fetch_20newsgroups
categories = [
'rec.motorcycles',
'rec.sport.baseball',
'comp.graphics',
'sci.space',
'talk.politics.mideast'
]
ng5 = fetch_20newsgroups(categories=categories)
documents = ng5.data

# %%
labels=ng5.target

# %% [markdown]
# ### Preprocessing

# %%
data=[]
for doc in documents:
    data.append(simple_preprocess(remove_stopwords(doc)))
print(len(data),"\n",data[0])
# Out:
# 2936
#  ['from', 'tedward', 'cs', 'cornell', 'edu', 'edward', 'ted', 'fischer', 'subject', 're', 'pleasant', 'yankee', 'surprises', 'organization', 'cornell', 'univ', 'cs', 'dept', 'ithaca', 'ny', 'lines', 'in', 'article', 'apr', 'alleg', 'edu', 'luriem', 'alleg', 'edu', 'michael', 'lurie', 'the', 'liberalizer', 'writes', 'actually', 'kind', 'liked', 'abott', 'trade', 'we', 'trade', 'rookie', 'the', 'year', 'snow', 'don', 'mattingly', 'years', 'why', 'bother', 'willing', 'wagers', 'snow', 'doesn', 'win', 'roy', 'mattingly', 'baseball', 'years', 'skeptical', 'first', 'don', 'think', 'snow', 'good', 'player', 'losing', 'team', 'skeptical', 'second', 'back', 'mattingly', 'year', 'players', 'play', 'not', 'many', 'didn', 'chronic', 'problems', 'could', 'wrong', 'both', 'think', 'that', 'smart', 'way', 'bet', 'cheers', 'valentine']

# %%
labels[0],ng5.target_names[labels[0]]
# Out:
# (2, 'rec.sport.baseball')

# %% [markdown]
# ## Term Document Frequency Matrix

# %%
joined_data=[]
for doc in data:
    joined_data.append(" ".join(doc))

# %%
tf=TfidfVectorizer(input='content',lowercase=False, use_idf=True,min_df=1, sublinear_tf=False)
matrix=tf.fit_transform(joined_data)
vocabulary = tf.vocabulary_

# %% [markdown]
# ## Embedding
# ### Word2Vec

# %%
model = Word2Vec(
        data,
        size=150,#taille du vecteur d'embedding pour chaque mot
        window=10,
        min_count=1,
        workers=10)
model.train(data, total_examples=len(data), epochs=10)
# Out:
# (5030564, 5221380)

# %%
model.wv.most_similar(positive="team",topn=6)
# Out:
# /home/paul/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('teams', 0.8928622007369995),
#  ('winning', 0.8687264919281006),
#  ('contribution', 0.8442803025245667),
#  ('braves', 0.8390316963195801),
#  ('win', 0.8292621970176697),
#  ('offensive', 0.8258484601974487)]

# %% [markdown]
# ### FastText

# %%
model = FastText(
        data,
        size=150,#taille du vecteur d'embedding pour chaque mot
        window=10,
        min_count=1,
        workers=10)
model.build_vocab(data,update=True)
model.train(data, total_examples=len(data), epochs=10)

# %% [markdown]
# ### Sans tenir compte de TF-IDF

# %%
D=[]
for document in data:
    D_doc=[]
    for mot in document:
        D_doc.append(model.wv.word_vec(mot))
    D.append(D_doc)

# %% [markdown]
# ###  En tenant compte de TF-IDF

# %%
D=[]
for index_doc, document in enumerate(data):
    D_doc=[]
    for mot in document:
        index_mot=vocabulary[mot]
        valeur_tf_idf=np.array(matrix[index_doc].todense())[0][index_mot]
        D_doc.append(valeur_tf_idf*model.wv.word_vec(mot))
    D.append(D_doc)

# %%
len(D),len(D[0]),len(D[0][0])
# Out:
# (2936, 90, 150)

# %%
for idx, document in enumerate(D):
    if len(document)==0:
        print("doc vide", idx)

# %% [markdown]
# Pas de document vide cette fois ci !

# %% [markdown]
# ## SVD

# %%
M2=[]### document représenté par u1 
M3=[]### document représenté par u1 + u2 
svd = TruncatedSVD(n_components=2, n_iter=7, random_state=42)

for document in D:
    svd.fit(document)
    
    M2.append(svd.components_[0])#[0] to transform 2D array to 1D
    
    M3.append(svd.components_[0]+svd.components_[1])#u1 + u2

# %%
len(M2)
# Out:
# 2936

# %% [markdown]
# ## Clustering
# ### K-Means

# %%
M3[1]
# Out:
# array([-0.05425847,  0.22092958,  0.05363808,  0.03158588, -0.07861505,
#        -0.12519222,  0.09059097, -0.02894248,  0.0414011 ,  0.07452008,
#         0.10656258, -0.07396282, -0.04671388,  0.04212774, -0.00159891,
#        -0.10773946,  0.01034495, -0.04825977,  0.01742988, -0.09233985,
#        -0.06472858, -0.14539967,  0.17397474, -0.0113096 ,  0.05481482,
#        -0.02100523, -0.09173417,  0.00965722, -0.19419228, -0.06262238,
#        -0.11515515,  0.14412242, -0.2169101 , -0.10075957, -0.18437849,
#         0.23748262,  0.09230109,  0.08324189, -0.11864592, -0.11788154,
#         0.0149489 , -0.00148363, -0.08614697,  0.20878181,  0.00591   ,
#         0.20258087,  0.02724553,  0.17658874, -0.01293344,  0.06443445,
#         0.14898768,  0.00307503, -0.0156563 , -0.2288028 ,  0.21073201,
#        -0.23211351, -0.07149783,  0.05701862, -0.21425876,  0.19149524,
#         0.13488552,  0.10893671,  0.11961426, -0.07410432,  0.04248217,
#        -0.02930151,  0.07460451, -0.05147269, -0.03418776, -0.00945701,
#         0.03164889, -0.10680962,  0.02349666, -0.04860535, -0.03529205,
#        -0.23924877,  0.19990945, -0.01262421,  0.21745881,  0.1377812 ,
#        -0.13138276, -0.0177551 ,  0.12116566, -0.12066738, -0.1300726 ,
#        -0.18000323, -0.0221809 , -0.09779291, -0.05194536,  0.03486419,
#        -0.02860016, -0.07595323, -0.01092101, -0.06174839, -0.16202189,
#         0.10493305, -0.06584708,  0.03153548,  0.12149475, -0.14102596,
#         0.05548653,  0.07955036, -0.087659  ,  0.04055082,  0.11451997,
#         0.07426528,  0.11256517, -0.10797337, -0.1333828 ,  0.02180884,
#        -0.10487612, -0.33393005, -0.03716666,  0.08660693,  0.16247377,
#         0.14631781,  0.17080061,  0.13372445,  0.05792743, -0.11518352,
#         0.01612606, -0.1507132 , -0.09500709, -0.18187308, -0.07870482,
#        -0.02523929, -0.01723716, -0.16439398, -0.05726612, -0.0631957 ,
#         0.12035665, -0.00468105,  0.12328994,  0.1286962 , -0.02392839,
#         0.11434342,  0.03814163,  0.04316303, -0.04706661,  0.22046094,
#         0.06311447, -0.24894984, -0.04809274, -0.15551198, -0.00261318,
#         0.08922046,  0.11192861,  0.19440098,  0.03645154,  0.0079357 ],
#       dtype=float32)

# %%
kmeans = KMeans(n_clusters=5,
               init='k-means++',
               n_init=10,
               n_jobs=-1).fit(M3)

# %%
y_kmeans = kmeans.predict(M3)

# %%
y_kmeans[0:10]
# Out:
# array([3, 3, 4, 3, 0, 3, 3, 4, 4, 2], dtype=int32)

# %%
y_kmeans.shape
# Out:
# (2936,)

# %%
print("%.3f" % adjusted_rand_score(labels, y_kmeans), "%.3f" % accuracy_score(labels, y_kmeans), "%.3f" % normalized_mutual_info_score(labels, y_kmeans))
# Out:
# 0.183 0.095 0.239
# /home/paul/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# Avant le preprocessing, on avait
# (ARI, Clustering Accuracy et NMI)
# (0.0454, 0.194, 0.0620)

# %% [markdown]
# # NG20
# ## Data

# %%
from sklearn.datasets import fetch_20newsgroups

ng20 = fetch_20newsgroups()
documents = ng20.data
labels=ng20.target

# %% [markdown]
# ### Preprocessing

# %%
data=[]
for doc in documents:
    data.append(simple_preprocess(remove_stopwords(doc)))
print(len(data),"\n",data[0])
# Out:
# 11314
#  ['from', 'lerxst', 'wam', 'umd', 'edu', 'where', 'thing', 'subject', 'what', 'car', 'this', 'nntp', 'posting', 'host', 'rac', 'wam', 'umd', 'edu', 'organization', 'university', 'maryland', 'college', 'park', 'lines', 'wondering', 'enlighten', 'car', 'saw', 'day', 'it', 'door', 'sports', 'car', 'looked', 'late', 'early', 'it', 'called', 'bricklin', 'the', 'doors', 'small', 'in', 'addition', 'bumper', 'separate', 'rest', 'body', 'this', 'know', 'if', 'tellme', 'model', 'name', 'engine', 'specs', 'years', 'production', 'car', 'made', 'history', 'info', 'funky', 'looking', 'car', 'mail', 'thanks', 'il', 'brought', 'neighborhood', 'lerxst']

# %%
labels[0],ng20.target_names[labels[0]]
# Out:
# (7, 'rec.autos')

# %% [markdown]
# ## Term Document Frequency Matrix

# %%
joined_data=[]
for doc in data:
    joined_data.append(" ".join(doc))

# %%
tf=TfidfVectorizer(input='content',lowercase=False, use_idf=True,min_df=1, sublinear_tf=False)
matrix=tf.fit_transform(joined_data)
vocabulary = tf.vocabulary_

# %% [markdown]
# ## Embedding
# ### Word2Vec

# %%
model = Word2Vec(
        data,
        size=150,#taille du vecteur d'embedding pour chaque mot
        window=10,
        min_count=1,
        workers=10)
model.train(data, total_examples=len(data), epochs=10)
# Out:
# (19784221, 20960470)

# %%
model.wv.most_similar(positive="team",topn=6)
# Out:
# /home/paul/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('teams', 0.8004267811775208),
#  ('talent', 0.7393660545349121),
#  ('playoffs', 0.7265616059303284),
#  ('score', 0.711507260799408),
#  ('nhl', 0.7113915085792542),
#  ('season', 0.7086697816848755)]

# %% [markdown]
# ### FastText

# %%
model = FastText(
        data,
        size=150,#taille du vecteur d'embedding pour chaque mot
        window=10,
        min_count=1,
        workers=10)
model.build_vocab(data,update=True)
model.train(data, total_examples=len(data), epochs=10)

# %% [markdown]
# ### Sans tenir compte de TF-IDF

# %%
D=[]
for document in data:
    D_doc=[]
    for mot in document:
        D_doc.append(model.wv.word_vec(mot))
    D.append(D_doc)

# %% [markdown]
# ###  En tenant compte de TF-IDF

# %%
D=[]
for index_doc, document in enumerate(data):
    D_doc=[]
    for mot in document:
        index_mot=vocabulary[mot]
        valeur_tf_idf=np.array(matrix[index_doc].todense())[0][index_mot]
        D_doc.append(valeur_tf_idf*model.wv.word_vec(mot))
    D.append(D_doc)

# %%
len(D),len(D[0]),len(D[0][0])
# Out:
# (11314, 71, 150)

# %%
for idx, document in enumerate(D):
    if len(document)==0:
        print("doc vide", idx)

# %% [markdown]
# Pas de document vide cette fois ci !

# %% [markdown]
# ## SVD

# %%
M2=[]### document représenté par u1 
M3=[]### document représenté par u1 + u2 
svd = TruncatedSVD(n_components=2, n_iter=7, random_state=42)

for document in D:
    svd.fit(document)
    
    M2.append(svd.components_[0])#[0] to transform 2D array to 1D
    
    M3.append(svd.components_[0]+svd.components_[1])#u1 + u2

# %%
len(M2)
# Out:
# 11314

# %% [markdown]
# ## Clustering
# ### K-Means

# %%
M2[1]
# Out:
# array([-0.05333504, -0.08073763,  0.16194862,  0.05326918,  0.03032059,
#         0.13754734, -0.03140682,  0.00962752, -0.07226534,  0.06386106,
#         0.03947318, -0.11046065, -0.02492899,  0.07049695,  0.01256578,
#         0.08367119, -0.11132262,  0.0094699 , -0.08305372, -0.10545208,
#        -0.1587091 ,  0.02643983,  0.10635555, -0.11709782,  0.00334228,
#        -0.06901493,  0.03376008, -0.15210119,  0.0806324 , -0.04880366,
#         0.09715441, -0.05574331, -0.03516318, -0.06920102, -0.11056875,
#        -0.03163147, -0.0568638 , -0.0503787 ,  0.01621327, -0.06817595,
#        -0.00192615, -0.06994791,  0.03021749, -0.07572728, -0.06228599,
#        -0.08525594, -0.12891284, -0.03415612,  0.2225135 , -0.04164992,
#         0.08930891,  0.0032893 , -0.03262468,  0.01462215, -0.0314008 ,
#        -0.09598184,  0.07404144,  0.06649946,  0.01122475,  0.08458804,
#         0.09324378, -0.01743558, -0.01637261, -0.06072316, -0.05402777,
#        -0.0817707 ,  0.00663733, -0.09959578, -0.06942805,  0.00619907,
#        -0.02949468, -0.07693322,  0.10047979, -0.09147993,  0.03094801,
#        -0.12694688, -0.0467531 , -0.03154399,  0.11184999, -0.05803838,
#         0.10242918,  0.05290905,  0.04843323, -0.05637624,  0.03462159,
#         0.0824317 , -0.00933568, -0.06567115, -0.02592104, -0.03741886,
#        -0.02722172, -0.03319016,  0.06942672,  0.11240283, -0.02422282,
#         0.03100745, -0.06044859,  0.01730567,  0.00696724,  0.06853543,
#        -0.05962039, -0.10915769,  0.02471339, -0.11572772,  0.01801966,
#        -0.12017167,  0.02885423,  0.06446376,  0.12038224,  0.05500697,
#         0.21633396, -0.13755056, -0.21995771, -0.12216832, -0.04464969,
#         0.03454584, -0.11280318, -0.09201644,  0.02562184,  0.02352582,
#         0.1693243 , -0.06718214,  0.09712476, -0.03048436, -0.0393055 ,
#         0.06128291, -0.03106968, -0.08178095,  0.02362644,  0.12431521,
#        -0.14674369,  0.06099486, -0.04383262,  0.10737965, -0.06446066,
#         0.20757666,  0.07386473, -0.02971306,  0.02132354, -0.01372284,
#         0.00896609, -0.04131386, -0.04380467,  0.10454238,  0.11844605,
#        -0.15752405, -0.04422016, -0.06474291, -0.07930989,  0.01825735],
#       dtype=float32)

# %%
kmeans = KMeans(n_clusters=20,
               init='k-means++',
               n_init=10,
               n_jobs=-1).fit(M3)

# %%
y_kmeans = kmeans.predict(M3)

# %%
y_kmeans[0:10]
# Out:
# array([12,  1,  7,  9, 19, 14,  7,  1, 19,  1], dtype=int32)

# %%
y_kmeans.shape
# Out:
# (11314,)

# %%
print("%.3f" % adjusted_rand_score(labels, y_kmeans), "%.3f" % accuracy_score(labels, y_kmeans), "%.3f" % normalized_mutual_info_score(labels, y_kmeans))
# Out:
# 0.085 0.085 0.182
# /home/paul/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# # Reuteurs_8
# ## Data

# %%
all_files = os.listdir("./reuters8_data")   

print(all_files)
# Out:
# ['reuters8_labels.txt', 'reuters8_embeddings.txt', 'reuters8_raw.txt']

# %%
label_file  = open( "./reuters8_data/reuters8_labels.txt" );
text_labels=[]

for line in label_file.readlines():
    
    y =  line.splitlines()
    
    text_labels.append(y[0])

len(text_labels)
# Out:
# 5485

# %%
text_labels[0:10]
unique_labels=set(text_labels)
unique_labels
# Out:
# {'acq', 'crude', 'earn', 'grain', 'interest', 'money-fx', 'ship', 'trade'}

# %%
label_dict= dict(zip(unique_labels, range(0,8)))#{'cisi':0,'cran':1,'med.':2}
label_dict
# Out:
# {'crude': 0,
#  'ship': 1,
#  'acq': 2,
#  'grain': 3,
#  'interest': 4,
#  'money-fx': 5,
#  'earn': 6,
#  'trade': 7}

# %%
labels=[]
for label in text_labels:
    labels.append(label_dict[label])
len(labels)
# Out:
# 5485

# %%
labels[0:10]
# Out:
# [6, 2, 6, 6, 6, 6, 6, 6, 6, 6]

# %%
tmp = []

f = open('./reuters8_data/reuters8_raw.txt', 'r')
    
tmp = f.read()
tmp=tmp.split("\n")
f.close()

# %%
len(tmp)
# Out:
# 5485

# %%
tmp[0]
# Out:
# 'champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares'

# %% [markdown]
# Le dernier document est vide !

# %%
tmp[5485]
# Out:
# ''

# %%
tmp.pop(5485)
# Out:
# ''

# %% [markdown]
# ### Preprocessing

# %%
data=[]
for doc in tmp:
    data.append(simple_preprocess(remove_stopwords(doc)))
print(len(data),"\n",data[0])
# Out:
# 5485
#  ['champion', 'products', 'ch', 'approves', 'stock', 'split', 'champion', 'products', 'said', 'board', 'directors', 'approved', 'stock', 'split', 'common', 'shares', 'shareholders', 'record', 'april', 'company', 'said', 'board', 'voted', 'recommend', 'shareholders', 'annual', 'meeting', 'april', 'increase', 'authorized', 'capital', 'stock', 'mln', 'mln', 'shares']

# %%
labels[0],text_labels[0]
# Out:
# (6, 'earn')

# %% [markdown]
# ## Term Document Frequency Matrix

# %%
joined_data=[]
for doc in data:
    joined_data.append(" ".join(doc))

# %%
tf=TfidfVectorizer(input='content',lowercase=False, use_idf=True,min_df=1, sublinear_tf=False)
matrix=tf.fit_transform(joined_data)
vocabulary = tf.vocabulary_

# %% [markdown]
# ## Embedding
# ### Word2Vec

# %%
model = Word2Vec(
        data,
        size=150,#taille du vecteur d'embedding pour chaque mot
        window=10,
        min_count=1,
        workers=10)
model.train(data, total_examples=len(data), epochs=10)
# Out:
# (2968498, 3487600)

# %%
model.wv.most_similar(positive="products",topn=6)
# Out:
# /home/paul/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('components', 0.836511492729187),
#  ('automotive', 0.7903476357460022),
#  ('food', 0.7896127700805664),
#  ('carbon', 0.7882393598556519),
#  ('manufacturing', 0.7775107622146606),
#  ('specialty', 0.7744584679603577)]

# %% [markdown]
# ### FastText

# %%
model = FastText(
        data,
        size=150,#taille du vecteur d'embedding pour chaque mot
        window=10,
        min_count=1,
        workers=10)
model.build_vocab(data,update=True)
model.train(data, total_examples=len(data), epochs=10)

# %% [markdown]
# ### Sans tenir compte de TF-IDF

# %%
D=[]
for document in data:
    D_doc=[]
    for mot in document:
        D_doc.append(model.wv.word_vec(mot))
    D.append(D_doc)

# %% [markdown]
# ###  En tenant compte de TF-IDF

# %%
D=[]
for index_doc, document in enumerate(data):
    D_doc=[]
    for mot in document:
        index_mot=vocabulary[mot]
        valeur_tf_idf=np.array(matrix[index_doc].todense())[0][index_mot]
        D_doc.append(valeur_tf_idf*model.wv.word_vec(mot))
    D.append(D_doc)

# %%
len(D),len(D[0]),len(D[0][0])
# Out:
# (5485, 35, 150)

# %%
for idx, document in enumerate(D):
    if len(document)==0:
        print("doc vide", idx)

# %% [markdown]
# Pas de document vide cette fois ci !

# %% [markdown]
# ## SVD

# %%
M2=[]### document représenté par u1 
M3=[]### document représenté par u1 + u2 
svd = TruncatedSVD(n_components=2, n_iter=7, random_state=42)

for document in D:
    svd.fit(document)
    
    M2.append(svd.components_[0])#[0] to transform 2D array to 1D
    
    M3.append(svd.components_[0]+svd.components_[1])#u1 + u2

# %%
len(M2)
# Out:
# 5485

# %% [markdown]
# ## Clustering
# ### K-Means

# %%
M3[1]
# Out:
# array([-0.13326533,  0.04897722,  0.13190456, -0.02079223, -0.1870349 ,
#        -0.04616622, -0.23015435,  0.19638541, -0.07431839, -0.05102956,
#        -0.31388327,  0.02875617,  0.00297901,  0.03184329, -0.07873619,
#         0.13014089,  0.07326851, -0.06016132,  0.01235911, -0.04291956,
#        -0.12757963, -0.04865028,  0.156371  ,  0.0737194 , -0.03474683,
#        -0.18076757, -0.09210962, -0.07439608, -0.3335455 ,  0.0269329 ,
#         0.21180043, -0.01792526, -0.07870208,  0.10723796,  0.04082163,
#         0.04926269, -0.08106211, -0.20837867,  0.25681883,  0.00791642,
#         0.09015019, -0.16349392,  0.06640866, -0.07814196, -0.06383808,
#         0.03096112,  0.04367607,  0.141172  , -0.03937015,  0.03099206,
#         0.09628212, -0.00897802, -0.17094743,  0.02829949,  0.04930368,
#         0.06079855, -0.17513156,  0.15613401,  0.01814906,  0.20952861,
#         0.09908448, -0.00963654, -0.0189178 , -0.07059503, -0.01678999,
#        -0.15164012, -0.15680343, -0.02614288, -0.06565633,  0.01417875,
#        -0.02643368,  0.07705094, -0.00328141,  0.00620577,  0.07130629,
#         0.16151606,  0.14022252, -0.06520663,  0.13681777,  0.02055424,
#         0.02922952, -0.04606386, -0.20891958,  0.03070038, -0.00409802,
#         0.13233204, -0.19792171, -0.06752411,  0.14310122,  0.03985577,
#        -0.0746079 ,  0.02933954, -0.19922307, -0.05035001,  0.1729476 ,
#         0.03847919,  0.07859948, -0.16049553, -0.18794683, -0.08534871,
#        -0.03986865,  0.06115134, -0.03355108,  0.02196232,  0.16752005,
#        -0.09289456,  0.03990529, -0.03605767, -0.23819864,  0.01931879,
#        -0.10249256, -0.04094631, -0.02922269, -0.02132967, -0.06431395,
#        -0.14208439, -0.06610786,  0.05067807,  0.21636686,  0.09996807,
#        -0.08891244,  0.16416244, -0.03331733, -0.16727966,  0.11650361,
#         0.01511756, -0.0513058 , -0.00512039, -0.06185613,  0.07403857,
#         0.09590122, -0.29015923,  0.12474007, -0.07897609,  0.16058478,
#        -0.1641599 , -0.0230435 , -0.08992353,  0.13450712, -0.10993527,
#         0.12161352,  0.07838189, -0.12184472, -0.07697432, -0.10485528,
#         0.00325508, -0.0690114 , -0.00838043, -0.13897257, -0.25811142],
#       dtype=float32)

# %%
kmeans = KMeans(n_clusters=8,
               init='k-means++',
               n_init=10,
               n_jobs=-1).fit(M3)

# %%
y_kmeans = kmeans.predict(M3)

# %%
y_kmeans[0:10]
# Out:
# array([0, 0, 1, 1, 1, 7, 7, 1, 1, 6], dtype=int32)

# %%
y_kmeans.shape
# Out:
# (5485,)

# %%
print("%.3f" % adjusted_rand_score(labels, y_kmeans), "%.3f" % accuracy_score(labels, y_kmeans), "%.3f" % normalized_mutual_info_score(labels, y_kmeans))
# Out:
# 0.237 0.271 0.342
# /home/paul/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ## Conclusion
# ### En utilisant Word2Vec
#
# Methode (ARI, Clustering Accuracy et NMI)/Dataset | Classic | NG5 | NG20 | R8
# --- | --- | --- | --- | ---
# document représenté par u 1 sans utiliser tf-idf | (0.731, 0.234, 0.659)| (0.120, 0.229, 0.252) | (0.103, 0.048, 0.235) |  0.397 0.010 0.538
# document représenté par u 1 en utilisant tf-idf | (0.922, 0.264, 0.877) | (0.450, 0.193, 0.463) | (0.175, 0.033, 0.305) |   0.369 0.014 0.496
# document représenté par u 1 + u 2 sans utiliser tf-idf | (0.672, 0.268, 0.617) | (0.144, 0.148, 0.199) | (0.062, 0.060, 0.163) |  (0.200, 0.071, 0.305)
# document représenté par u 1 + u 2 en utilisant tf-idf | (0.705, 0.0576, 0.630) | (0.320, 0.219, 0.330) | (0.146, 0.0597, 0.264) |  0.188 0.051 0.331

# %% [markdown]
# ### En utilisant fastText
#
# Methode (ARI, Clustering Accuracy et NMI)/Dataset | Classic | NG5 | NG20 | R8
# --- | --- | --- | --- | ---
# document représenté par u 1 sans utiliser tf-idf | 0.923 0.364 0.884 | 0.039 0.199 0.069 | 0.023 0.049 0.077 | 0.358 0.137 0.469
# document représenté par u 1 en utilisant tf-idf  | 0.871 0.955 0.813| 0.187 0.215 0.240 | 0.107 0.049 0.217 | 0.345 0.130 0.453
# document représenté par u 1 + u 2 sans utiliser tf-idf  | 0.766 0.037 0.710 | 0.029 0.198 0.034 | 0.015 0.041 0.055 | 0.210 0.112 0.324
# document représenté par u 1 + u 2 en utilisant tf-idf | 0.745 0.907 0.667 | 0.183 0.095 0.239 | 0.085 0.085 0.182 | 0.237 0.271 0.342

# %% [markdown]
# 1. [Classic 3](#Classic_3)
# - [NG5](#NG5)
# - [NG20](#NG20)
# - [Reuters8](#Reuteurs_8)
